# %%
mess = "Hello world"
for i in mess:
    print(mess[::-1])

# %%
for item in mess:
    print(item)
    print(item)

# %%
for i, v in enumerate(mess):
    print(i,v)

# %%
for i in range(0, 10):
    pass

# %%
for i in range(0,30):
    if(i%3 == 0 and i%5 == 0):
        print("frizz buzz")
    elif(i%3 ==0):
        print("frizz")
    elif(i%5==0):
        print("Buzz")

# %%
print(mess[::-1].upper())
print(mess.lower())
print(mess.capitalize())
words = "  --  h-ello world. // "
print(len(words))
mess.strip("-")
mess.split("o")

# %%
mess_list = mess.split()
mess_list

# %%
"  ".join(mess_list)

# %%
emails = "sum@gmail.com, zun@gmail.com, sum@hotmail.com"
emails.split("@")

# %%
my_list = [1,2,3,4,5,6,7,8,9,0]

# %%
my_list+[1,23]
my_list.append("sam")
my_list.insert(1, "sam")
my_list

# %%
my_list = [1, 2, 3, 3, [2, 3, ["Ramesh"], 45, ["bingo"]]]
for i in my_list:
   for j in my_list:
      print my_list

# %%
my_list=[2,3,41,['ram','suresh',1,2,3,["vipul",["good"]]]]
my_list[3][5][1][0] = "goody"
my_list[3][5][1][0][0]

# %%
my_tup=(1,2,3,34, "r", "s")
my_tup.count(1)
my_tup.index(3)

# %% [markdown]
# tup is with comma and () but mainly comma
# MUST have comma just () is still a string
# immutable +splicing +index + count

# %%
string_1 = "hello world"
newString = ""
num = -1
for i in string_1:
    newString += string_1[num] * 2
    num = num - 1
print(newString)

# %%
input_list = [(10,20,40), (40,50,60), (70,80,90)]

new_list = []


for i in input:
    new_list.append(i[0:2] + (100,))
print(new_list)

# %%
print("Enter a word: ")
word = input("Enter a word: ")

reversed_word = word[::-1]

if word == reversed_word:
    print("True")
else:
    print("False")

# %%
numbers = (4, 7, 2, 9, 1)

largest = numbers[0]

for num in numbers:
    if num > largest:
        largest = num

print(largest)

# %% [markdown]
# 11:30

# %%
my_set={1,2,3,4,5,6,7.8,8}
my_set

# %%
my_list = [1,2,2,3,4,100]
my_set = set(my_list)
print(my_set)
